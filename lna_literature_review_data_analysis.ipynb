# %%
from pathlib import Path 

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scienceplots
import numpy as np

plt.style.use(['ieee', 'nature'])

# %matplotlib inline

# %%
dir = Path('./data/')
dir
# Out:
# PosixPath('data')

# %%
lnareviewdf = pd.read_csv(dir/'us_lna_survey.csv')

lnareviewdf
# Out:
#                            Group                   Work         Technology  \
# 0                     EI-TUDelft           PGuoJSSC2022     180nm CMOS-BCD
# 1                     EI-TUDelft           MTanJSSC2018       180nm HVCMOS
# 2      MEDR/CICS-MIT/ButterflyIQ          KChenJSSC2015     180nm CMOS-BCD
# 3                     EI-TUDelft          EKangJSSC2020     180nm CMOS-BCD
# 4               KNIT-SK/SK Hynix       JYongUmTCSII2021         180nm CMOS
# 5                     MEDep. ITU        ICicekTUFFC2005     800nm CMOS-BCD
# 6    ELG Lab./SCIS Stanford Uni.      IOWygantTUFFC2009       1.5µm HVCMOS
# 7                       CICS-MIT          KChenJSSC2013       180nm HVCMOS
# 8          DIII-Pavia Uni. Italy     MSauttoESSCIRC2014      180nm BCD-SOI
# 9                     EI-TUDelft       CChenESSCIRC2015     180nm CMOS-BCD
# 10                     MITUS-TUD              DDias2025     28nm TSMC CMOS
# 11                 KAIST-Samsung           JLeeJSSC2021   180nm 1P6M CMOS
# 12                    EI-TUDelft          EKangJSSC2018     180nm CMOS-BCD
# 13                   CTI-Hitachi      YIgarashiJSSC2019  180nm HV SOI CMOS
# 14             EEC-Georgia Tech.         GJungTBCAS2018     180nm CMOS BCD
# 15             EEC-Georgia Tech.           JLimJSSC2020     180nm CMOS BCD
# 16                 KAIST-Samsung         KJeongJSSC2023     180nm CMOS BCD
# 17  Robert-Bosch, Standford Uni.          MChanJSSC2017    28nm FDSOI CMOS
# 18                    EI-TUDelft           PGuoJSSC2024     180nm CMOS BCD
# 19               EED-TUEindhoven          MZhouJSSC2021          40nm CMOS
# 20              NUST-South Korea      ABanuajiTCSII2014         180nm CMOS
# 21  EEC-British Columbia Uni. CA    PBehnamfarTBCAS2015      250nm HV CMOS
# 22             EEC-Georgia Tech.  ARezanitabarTBCAS2022     180nm CMOS BCD
# 23                   BioEng. UCL       GPeytonTBCAS2018         350nm CMOS
# 24             EEC-Georgia Tech.      MRashidULTSYM2014         350nm CMOS
#
#    Transducer Type  Supply(V)    Lmin Pitch(µm) LNA Architecture  \
# 0              PZT        1.8   180nm       100            CL-CA
# 1              PZT        1.9   180nm       100              TIA
# 2             CMUT        1.8   180nm       250              TIA
# 3             CMUT        1.8   180nm       400            CL-CA
# 4               NR        1.8   180nm        NR            OL-VA
# 5             CMUT        5.0   800nm       200              TIA
# 6             CMUT        5.0  1500nm       250              TIA
# 7             CMUT        1.8   180nm       300              TIA
# 8             CMUT        1.8   180nm        NR              TIA
# 9              PZT        1.8   180nm       200            CL-VA
# 10             PZT        1.8   150nm        NR            OL-VA
# 11            PMUT        1.5   180nm       250            OL-VA
# 12             PZT        1.8   180nm       150            CL-VA
# 13             PZT        1.8   180nm       300            OL-VA
# 14        PZT/CMUT        1.8   180nm       500            CL-VA
# 15            CMUT        5.0   180nm        25              TIA
# 16             PZT       20.0   180nm        NR            OL-VA
# 17            CMUT        1.0    28nm       250              TIA
# 18             PZT        1.8   180nm       125              TIA
# 19            CMUT        1.2    40nm       102              TIA
# 20            CMUT        1.1   180nm        NR              TIA
# 21            CMUT        3.3   350nm        NR              TIA
# 22            CMUT        1.8   180nm       150              TIA
# 23             PZT        3.3   350nm        NR            OL-VA
# 24            CMUT        3.3   350nm        NR              TIA
#
#    Pitch Matched Transducer Capacitance (pF)  ... IRNC @ F0 (pA/\sqrt{Hz})  \
# 0            Yes                         1.0  ...                     1.31
# 1             No                         0.7  ...                     2.00
# 2             No                         2.0  ...                     0.41
# 3             No                          15  ...                      1.7
# 4             No                          NR  ...                       NR
# 5            Yes                         4.5  ...                       NR
# 6             No                         2.0  ...                     0.28
# 7            Yes                        40.0  ...                       NR
# 8             No                         5.0  ...                       NR
# 9            Yes                        ~3.5  ...                       NR
# 10            No                         1.4  ...                       NR
# 11           Yes                        15.4  ...                       NR
# 12            No                          NR  ...                       NR
# 13           Yes                          NR  ...                       NR
# 14           Yes                          15  ...                       NR
# 15            No                         2.0  ...                     0.18
# 16            No                          NR  ...                       NR
# 17           Yes                          NR  ...                       NR
# 18           Yes                         1.0  ...                      0.7
# 19           Yes                          25  ...                     3.10
# 20            NR                          NR  ...                      3.5
# 21            NR                          NR  ...                    0.448
# 22           Yes                        15.0  ...                       NR
# 23            No                          NR  ...                       NR
# 24            No                          NR  ...                     16.0
#
#    IRNV @ F0 (nV/\sqrt{Hz}) IRNA @ F0 (mPa/\sqrt{Hz}) PSRR @ F0(dBc)  \
# 0                        NR                        NR             26
# 1                        NR                        NR             16
# 2                        NR                        NR             NR
# 3                        NR                        NR             NR
# 4                       8.6                        NR             NR
# 5                       6.5                        NR             NR
# 6                        NR                       0.9             NR
# 7                      9.21                      0.55             47
# 8                      21.2                      0.55             20
# 9                       5.9                       0.6           45.0
# 10                      5.2                        NR             54
# 11                     19.3                        NR             NR
# 12                      7.9                       4.2             NR
# 13                     1.97                        NR             NR
# 14                      5.0                        NR             NR
# 15                     47.0                        NR             55
# 16                      7.0                        NR             NR
# 17                       NR                        NR             NR
# 18                       NR                        NR             NR
# 19                       NR                        NR           25.4
# 20                       NR                        NR             NR
# 21                       NR                        NR             NR
# 22                      8.6                        NR             NR
# 23                     5.42                        NR             NR
# 24                       NR                        NR             NR
#
#    Peak SNR@BW(dB) Power Dissipation(mW) Area (mm^2)  \
# 0             48.0                0.8000       0.025
# 1             42.0                0.7900       0.027
# 2             40.0                1.4000       0.028
# 3             51.0                5.2000       0.120
# 4            ~40.0                0.9600       0.025
# 5               NR                2.0000       0.040
# 6            ~40.0                9.0000          NR
# 7            ~40.0               14.3000      0.0825
# 8            ~40.0                1.0000       0.030
# 9            ~50.0                0.1350        0.01
# 10              NR                0.5500       0.008
# 11            57.9                0.1615       0.017
# 12           ~40.0                1.4200        0.12
# 13            55.0                0.7400        0.13
# 14            36.7                0.7000        0.13
# 15            36.0                0.7900       0.093
# 16            54.0                0.1600         0.2
# 17            60.0                3.8700        0.01
# 18            50.7                0.7910      0.0334
# 19            36.3                0.6000      0.0125
# 20           ~40.0                0.4202        0.15
# 21            45.0                1.0500        0.08
# 22           ~35.0                0.3720      0.0105
# 23           ~50.0                0.9000       0.034
# 24           ~40.0                0.5510      0.0077
#
#                                              DOI  \
# 0      https://doi.org/10.1109/JSSC.2022.3200160
# 1      https://doi.org/10.1109/JSSC.2018.2828826
# 2      https://doi.org/10.1109/JSSC.2015.2505714
# 3      https://doi.org/10.1109/JSSC.2020.3023618
# 4     https://doi.org/10.1109/TCSII.2021.3090424
# 5     https://doi.org/10.1109/TUFFC.2005.1563266
# 6        https://doi.org/10.1109/TUFFC.2009.1297
# 7      https://doi.org/10.1109/JSSC.2013.2274895
# 8   https://doi.org/10.1109/ESSCIRC.2014.6942108
# 9   https://doi.org/10.1109/ESSCIRC.2015.7313913
# 10                                           NaN
# 11     https://doi.org/10.1109/JSSC.2021.3049560
# 12     https://doi.org/10.1109/JSSC.2018.2820156
# 13     https://doi.org/10.1109/JSSC.2019.2921697
# 14    https://doi.org/10.1109/TBCAS.2018.2881909
# 15     https://doi.org/10.1109/JSSC.2020.2967551
# 16     https://doi.org/10.1109/JSSC.2023.3276130
# 17     https://doi.org/10.1109/JSSC.2017.2749425
# 18     https://doi.org/10.1109/JSSC.2024.3355854
# 19    https://doi.org/10.1109/TBCAS.2021.3135859
# 20    https://doi.org/10.1109/TCSII.2014.2327455
# 21    https://doi.org/10.1109/TBCAS.2015.2406777
# 22    https://doi.org/10.1109/TBCAS.2022.3205024
# 23    https://doi.org/10.1109/TBCAS.2018.2836915
# 24      https://doi.org/10.1109/ULTSYM.2014.0381
#
#                                                 Notes  \
# 0                                                 NaN
# 1   Originally observed effect of PSRR in inter-ch...
# 2   Defines an Acoustic Noise Efficiency Factor (A...
# 3                Establishes the basis of Pengs Work.
# 4    Uses a cross-coupled harmonic injection NMOS ...
# 5    Older work establishing which metrics to take...
# 6   Old technology with base work for CMUT-on-CMOS...
# 7    Very interesting charge-pump DC-DC converter ...
# 8    Defines a linearized approximation of the tra...
# 9    Very important base work defining the importa...
# 10                                                NaN
# 11                 Open Loop VA with 4-gain step PGA
# 12  Closed Loop (cap) folded cascode LNA with sing...
# 13  Open Loop differential pair with a pseudo-diff...
# 14  Closed Loop diff pair + CS output stage, resis...
# 15  CMUT-BSimulator Based Impedance  Calculator fo...
# 16  Rotating Single PZT Transducer insie Cabsule, ...
# 17  3 stage LNA-LPF-PGA based on inverter-based am...
# 18          "Capacitive Feedback TIA coupled to a PZT
# 19   Reference TIA implementation with noise figur...
# 20   Standard CMOS implementation of HV pulser usi...
# 21                                                NaN
# 22  First paper providing a reference microbeamfor...
# 23  Reference paper for implementing the testing s...
# 24  Quadrature FDM Simulated Results from Post Lay...
#
#                                           Unnamed: 28
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18   due to the PZT output impedance magnitude bei...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
# [25 rows x 29 columns]

# %%
lnareviewdf['PaperID'] = lnareviewdf['Work'].str.extract(r'([A-Z]{4,7}\d{4})$')

# %%
lnareviewdf['Architecture Category'] = lnareviewdf['LNA Architecture']
lnareviewdf['Transducer Type'] = lnareviewdf['Transducer Type'].apply(lambda x: 'BULK' if 'PZT' in x else x)
lnareviewdf = lnareviewdf.replace('NR', np.nan)
lnareviewdf['Area ($mm^2$)'] = lnareviewdf['Area (mm^2)'].astype(float)
lnareviewdf['-3dB BW (MHz)'] = lnareviewdf['-3dB BW (MHz)'].astype(float)
lnareviewdf['Peak SNR@BW(dB)'] = lnareviewdf['Peak SNR@BW(dB)'].str.lstrip('~').astype(float)
lnareviewdf['Power Dissipation(mW)'] = lnareviewdf['Power Dissipation(mW)'].astype(float)
lnareviewdf
# Out:
#                            Group                   Work         Technology  \
# 0                     EI-TUDelft           PGuoJSSC2022     180nm CMOS-BCD
# 1                     EI-TUDelft           MTanJSSC2018       180nm HVCMOS
# 2      MEDR/CICS-MIT/ButterflyIQ          KChenJSSC2015     180nm CMOS-BCD
# 3                     EI-TUDelft          EKangJSSC2020     180nm CMOS-BCD
# 4               KNIT-SK/SK Hynix       JYongUmTCSII2021         180nm CMOS
# 5                     MEDep. ITU        ICicekTUFFC2005     800nm CMOS-BCD
# 6    ELG Lab./SCIS Stanford Uni.      IOWygantTUFFC2009       1.5µm HVCMOS
# 7                       CICS-MIT          KChenJSSC2013       180nm HVCMOS
# 8          DIII-Pavia Uni. Italy     MSauttoESSCIRC2014      180nm BCD-SOI
# 9                     EI-TUDelft       CChenESSCIRC2015     180nm CMOS-BCD
# 10                     MITUS-TUD              DDias2025     28nm TSMC CMOS
# 11                 KAIST-Samsung           JLeeJSSC2021   180nm 1P6M CMOS
# 12                    EI-TUDelft          EKangJSSC2018     180nm CMOS-BCD
# 13                   CTI-Hitachi      YIgarashiJSSC2019  180nm HV SOI CMOS
# 14             EEC-Georgia Tech.         GJungTBCAS2018     180nm CMOS BCD
# 15             EEC-Georgia Tech.           JLimJSSC2020     180nm CMOS BCD
# 16                 KAIST-Samsung         KJeongJSSC2023     180nm CMOS BCD
# 17  Robert-Bosch, Standford Uni.          MChanJSSC2017    28nm FDSOI CMOS
# 18                    EI-TUDelft           PGuoJSSC2024     180nm CMOS BCD
# 19               EED-TUEindhoven          MZhouJSSC2021          40nm CMOS
# 20              NUST-South Korea      ABanuajiTCSII2014         180nm CMOS
# 21  EEC-British Columbia Uni. CA    PBehnamfarTBCAS2015      250nm HV CMOS
# 22             EEC-Georgia Tech.  ARezanitabarTBCAS2022     180nm CMOS BCD
# 23                   BioEng. UCL       GPeytonTBCAS2018         350nm CMOS
# 24             EEC-Georgia Tech.      MRashidULTSYM2014         350nm CMOS
#
#    Transducer Type  Supply(V)    Lmin Pitch(µm) LNA Architecture  \
# 0             BULK        1.8   180nm       100            CL-CA
# 1             BULK        1.9   180nm       100              TIA
# 2             CMUT        1.8   180nm       250              TIA
# 3             CMUT        1.8   180nm       400            CL-CA
# 4              NaN        1.8   180nm       NaN            OL-VA
# 5             CMUT        5.0   800nm       200              TIA
# 6             CMUT        5.0  1500nm       250              TIA
# 7             CMUT        1.8   180nm       300              TIA
# 8             CMUT        1.8   180nm       NaN              TIA
# 9             BULK        1.8   180nm       200            CL-VA
# 10            BULK        1.8   150nm       NaN            OL-VA
# 11            PMUT        1.5   180nm       250            OL-VA
# 12            BULK        1.8   180nm       150            CL-VA
# 13            BULK        1.8   180nm       300            OL-VA
# 14            BULK        1.8   180nm       500            CL-VA
# 15            CMUT        5.0   180nm        25              TIA
# 16            BULK       20.0   180nm       NaN            OL-VA
# 17            CMUT        1.0    28nm       250              TIA
# 18            BULK        1.8   180nm       125              TIA
# 19            CMUT        1.2    40nm       102              TIA
# 20            CMUT        1.1   180nm       NaN              TIA
# 21            CMUT        3.3   350nm       NaN              TIA
# 22            CMUT        1.8   180nm       150              TIA
# 23            BULK        3.3   350nm       NaN            OL-VA
# 24            CMUT        3.3   350nm       NaN              TIA
#
#    Pitch Matched Transducer Capacitance (pF)  ... PSRR @ F0(dBc)  \
# 0            Yes                         1.0  ...             26
# 1             No                         0.7  ...             16
# 2             No                         2.0  ...            NaN
# 3             No                          15  ...            NaN
# 4             No                         NaN  ...            NaN
# 5            Yes                         4.5  ...            NaN
# 6             No                         2.0  ...            NaN
# 7            Yes                        40.0  ...             47
# 8             No                         5.0  ...             20
# 9            Yes                        ~3.5  ...           45.0
# 10            No                         1.4  ...             54
# 11           Yes                        15.4  ...            NaN
# 12            No                         NaN  ...            NaN
# 13           Yes                         NaN  ...            NaN
# 14           Yes                          15  ...            NaN
# 15            No                         2.0  ...             55
# 16            No                         NaN  ...            NaN
# 17           Yes                         NaN  ...            NaN
# 18           Yes                         1.0  ...            NaN
# 19           Yes                          25  ...           25.4
# 20           NaN                         NaN  ...            NaN
# 21           NaN                         NaN  ...            NaN
# 22           Yes                        15.0  ...            NaN
# 23            No                         NaN  ...            NaN
# 24            No                         NaN  ...            NaN
#
#    Peak SNR@BW(dB) Power Dissipation(mW) Area (mm^2)  \
# 0             48.0                0.8000       0.025
# 1             42.0                0.7900       0.027
# 2             40.0                1.4000       0.028
# 3             51.0                5.2000       0.120
# 4             40.0                0.9600       0.025
# 5              NaN                2.0000       0.040
# 6             40.0                9.0000         NaN
# 7             40.0               14.3000      0.0825
# 8             40.0                1.0000       0.030
# 9             50.0                0.1350        0.01
# 10             NaN                0.5500       0.008
# 11            57.9                0.1615       0.017
# 12            40.0                1.4200        0.12
# 13            55.0                0.7400        0.13
# 14            36.7                0.7000        0.13
# 15            36.0                0.7900       0.093
# 16            54.0                0.1600         0.2
# 17            60.0                3.8700        0.01
# 18            50.7                0.7910      0.0334
# 19            36.3                0.6000      0.0125
# 20            40.0                0.4202        0.15
# 21            45.0                1.0500        0.08
# 22            35.0                0.3720      0.0105
# 23            50.0                0.9000       0.034
# 24            40.0                0.5510      0.0077
#
#                                              DOI  \
# 0      https://doi.org/10.1109/JSSC.2022.3200160
# 1      https://doi.org/10.1109/JSSC.2018.2828826
# 2      https://doi.org/10.1109/JSSC.2015.2505714
# 3      https://doi.org/10.1109/JSSC.2020.3023618
# 4     https://doi.org/10.1109/TCSII.2021.3090424
# 5     https://doi.org/10.1109/TUFFC.2005.1563266
# 6        https://doi.org/10.1109/TUFFC.2009.1297
# 7      https://doi.org/10.1109/JSSC.2013.2274895
# 8   https://doi.org/10.1109/ESSCIRC.2014.6942108
# 9   https://doi.org/10.1109/ESSCIRC.2015.7313913
# 10                                           NaN
# 11     https://doi.org/10.1109/JSSC.2021.3049560
# 12     https://doi.org/10.1109/JSSC.2018.2820156
# 13     https://doi.org/10.1109/JSSC.2019.2921697
# 14    https://doi.org/10.1109/TBCAS.2018.2881909
# 15     https://doi.org/10.1109/JSSC.2020.2967551
# 16     https://doi.org/10.1109/JSSC.2023.3276130
# 17     https://doi.org/10.1109/JSSC.2017.2749425
# 18     https://doi.org/10.1109/JSSC.2024.3355854
# 19    https://doi.org/10.1109/TBCAS.2021.3135859
# 20    https://doi.org/10.1109/TCSII.2014.2327455
# 21    https://doi.org/10.1109/TBCAS.2015.2406777
# 22    https://doi.org/10.1109/TBCAS.2022.3205024
# 23    https://doi.org/10.1109/TBCAS.2018.2836915
# 24      https://doi.org/10.1109/ULTSYM.2014.0381
#
#                                                 Notes  \
# 0                                                 NaN
# 1   Originally observed effect of PSRR in inter-ch...
# 2   Defines an Acoustic Noise Efficiency Factor (A...
# 3                Establishes the basis of Pengs Work.
# 4    Uses a cross-coupled harmonic injection NMOS ...
# 5    Older work establishing which metrics to take...
# 6   Old technology with base work for CMUT-on-CMOS...
# 7    Very interesting charge-pump DC-DC converter ...
# 8    Defines a linearized approximation of the tra...
# 9    Very important base work defining the importa...
# 10                                                NaN
# 11                 Open Loop VA with 4-gain step PGA
# 12  Closed Loop (cap) folded cascode LNA with sing...
# 13  Open Loop differential pair with a pseudo-diff...
# 14  Closed Loop diff pair + CS output stage, resis...
# 15  CMUT-BSimulator Based Impedance  Calculator fo...
# 16  Rotating Single PZT Transducer insie Cabsule, ...
# 17  3 stage LNA-LPF-PGA based on inverter-based am...
# 18          "Capacitive Feedback TIA coupled to a PZT
# 19   Reference TIA implementation with noise figur...
# 20   Standard CMOS implementation of HV pulser usi...
# 21                                                NaN
# 22  First paper providing a reference microbeamfor...
# 23  Reference paper for implementing the testing s...
# 24  Quadrature FDM Simulated Results from Post Lay...
#
#                                           Unnamed: 28      PaperID  \
# 0                                                 NaN     JSSC2022
# 1                                                 NaN     JSSC2018
# 2                                                 NaN     JSSC2015
# 3                                                 NaN     JSSC2020
# 4                                                 NaN    TCSII2021
# 5                                                 NaN    TUFFC2005
# 6                                                 NaN    TUFFC2009
# 7                                                 NaN     JSSC2013
# 8                                                 NaN  ESSCIRC2014
# 9                                                 NaN  ESSCIRC2015
# 10                                                NaN          NaN
# 11                                                NaN     JSSC2021
# 12                                                NaN     JSSC2018
# 13                                                NaN     JSSC2019
# 14                                                NaN    TBCAS2018
# 15                                                NaN     JSSC2020
# 16                                                NaN     JSSC2023
# 17                                                NaN     JSSC2017
# 18   due to the PZT output impedance magnitude bei...     JSSC2024
# 19                                                NaN     JSSC2021
# 20                                                NaN    TCSII2014
# 21                                                NaN    TBCAS2015
# 22                                                NaN    TBCAS2022
# 23                                                NaN    TBCAS2018
# 24                                                NaN   ULTSYM2014
#
#     Architecture Category Area ($mm^2$)
# 0                   CL-CA        0.0250
# 1                     TIA        0.0270
# 2                     TIA        0.0280
# 3                   CL-CA        0.1200
# 4                   OL-VA        0.0250
# 5                     TIA        0.0400
# 6                     TIA           NaN
# 7                     TIA        0.0825
# 8                     TIA        0.0300
# 9                   CL-VA        0.0100
# 10                  OL-VA        0.0080
# 11                  OL-VA        0.0170
# 12                  CL-VA        0.1200
# 13                  OL-VA        0.1300
# 14                  CL-VA        0.1300
# 15                    TIA        0.0930
# 16                  OL-VA        0.2000
# 17                    TIA        0.0100
# 18                    TIA        0.0334
# 19                    TIA        0.0125
# 20                    TIA        0.1500
# 21                    TIA        0.0800
# 22                    TIA        0.0105
# 23                  OL-VA        0.0340
# 24                    TIA        0.0077
#
# [25 rows x 32 columns]

# %% [markdown]
# Assumming the designs reported in the state of the art aggregated in the database achieve the required input referred noise level for allowing a successfull deployment of the proposed applications, we can employ an efficiency factor for each design that is independant of the input referred noise level (which is important due to the big variability between works on the reporting of the figure of merit):
#
# $$ FoM_{LNA} = SNR + 10 \ log_{10} \left( \frac{B}{P_D} \right) \ (dB) $$
#
#
# This FoM is a modified Schreider FoM, to observe how each design scales SNR and Bandwidth without compromising on power dissipation. It is also important to note that distortion was not accounted in the SNR measure.

# %%
# introduce noise efficiency factor taking into acount only the power dissipation and the -3dB bandwidth
lnareviewdf['FoM$_{LNA}$ (dB)'] = lnareviewdf['Peak SNR@BW(dB)']  + 10 * np.log10( lnareviewdf['-3dB BW (MHz)'] / lnareviewdf['Power Dissipation(mW)'])
lnareviewdf
# Out:
#                            Group                   Work         Technology  \
# 0                     EI-TUDelft           PGuoJSSC2022     180nm CMOS-BCD
# 1                     EI-TUDelft           MTanJSSC2018       180nm HVCMOS
# 2      MEDR/CICS-MIT/ButterflyIQ          KChenJSSC2015     180nm CMOS-BCD
# 3                     EI-TUDelft          EKangJSSC2020     180nm CMOS-BCD
# 4               KNIT-SK/SK Hynix       JYongUmTCSII2021         180nm CMOS
# 5                     MEDep. ITU        ICicekTUFFC2005     800nm CMOS-BCD
# 6    ELG Lab./SCIS Stanford Uni.      IOWygantTUFFC2009       1.5µm HVCMOS
# 7                       CICS-MIT          KChenJSSC2013       180nm HVCMOS
# 8          DIII-Pavia Uni. Italy     MSauttoESSCIRC2014      180nm BCD-SOI
# 9                     EI-TUDelft       CChenESSCIRC2015     180nm CMOS-BCD
# 10                     MITUS-TUD              DDias2025     28nm TSMC CMOS
# 11                 KAIST-Samsung           JLeeJSSC2021   180nm 1P6M CMOS
# 12                    EI-TUDelft          EKangJSSC2018     180nm CMOS-BCD
# 13                   CTI-Hitachi      YIgarashiJSSC2019  180nm HV SOI CMOS
# 14             EEC-Georgia Tech.         GJungTBCAS2018     180nm CMOS BCD
# 15             EEC-Georgia Tech.           JLimJSSC2020     180nm CMOS BCD
# 16                 KAIST-Samsung         KJeongJSSC2023     180nm CMOS BCD
# 17  Robert-Bosch, Standford Uni.          MChanJSSC2017    28nm FDSOI CMOS
# 18                    EI-TUDelft           PGuoJSSC2024     180nm CMOS BCD
# 19               EED-TUEindhoven          MZhouJSSC2021          40nm CMOS
# 20              NUST-South Korea      ABanuajiTCSII2014         180nm CMOS
# 21  EEC-British Columbia Uni. CA    PBehnamfarTBCAS2015      250nm HV CMOS
# 22             EEC-Georgia Tech.  ARezanitabarTBCAS2022     180nm CMOS BCD
# 23                   BioEng. UCL       GPeytonTBCAS2018         350nm CMOS
# 24             EEC-Georgia Tech.      MRashidULTSYM2014         350nm CMOS
#
#    Transducer Type  Supply(V)    Lmin Pitch(µm) LNA Architecture  \
# 0             BULK        1.8   180nm       100            CL-CA
# 1             BULK        1.9   180nm       100              TIA
# 2             CMUT        1.8   180nm       250              TIA
# 3             CMUT        1.8   180nm       400            CL-CA
# 4              NaN        1.8   180nm       NaN            OL-VA
# 5             CMUT        5.0   800nm       200              TIA
# 6             CMUT        5.0  1500nm       250              TIA
# 7             CMUT        1.8   180nm       300              TIA
# 8             CMUT        1.8   180nm       NaN              TIA
# 9             BULK        1.8   180nm       200            CL-VA
# 10            BULK        1.8   150nm       NaN            OL-VA
# 11            PMUT        1.5   180nm       250            OL-VA
# 12            BULK        1.8   180nm       150            CL-VA
# 13            BULK        1.8   180nm       300            OL-VA
# 14            BULK        1.8   180nm       500            CL-VA
# 15            CMUT        5.0   180nm        25              TIA
# 16            BULK       20.0   180nm       NaN            OL-VA
# 17            CMUT        1.0    28nm       250              TIA
# 18            BULK        1.8   180nm       125              TIA
# 19            CMUT        1.2    40nm       102              TIA
# 20            CMUT        1.1   180nm       NaN              TIA
# 21            CMUT        3.3   350nm       NaN              TIA
# 22            CMUT        1.8   180nm       150              TIA
# 23            BULK        3.3   350nm       NaN            OL-VA
# 24            CMUT        3.3   350nm       NaN              TIA
#
#    Pitch Matched Transducer Capacitance (pF)  ... Peak SNR@BW(dB)  \
# 0            Yes                         1.0  ...            48.0
# 1             No                         0.7  ...            42.0
# 2             No                         2.0  ...            40.0
# 3             No                          15  ...            51.0
# 4             No                         NaN  ...            40.0
# 5            Yes                         4.5  ...             NaN
# 6             No                         2.0  ...            40.0
# 7            Yes                        40.0  ...            40.0
# 8             No                         5.0  ...            40.0
# 9            Yes                        ~3.5  ...            50.0
# 10            No                         1.4  ...             NaN
# 11           Yes                        15.4  ...            57.9
# 12            No                         NaN  ...            40.0
# 13           Yes                         NaN  ...            55.0
# 14           Yes                          15  ...            36.7
# 15            No                         2.0  ...            36.0
# 16            No                         NaN  ...            54.0
# 17           Yes                         NaN  ...            60.0
# 18           Yes                         1.0  ...            50.7
# 19           Yes                          25  ...            36.3
# 20           NaN                         NaN  ...            40.0
# 21           NaN                         NaN  ...            45.0
# 22           Yes                        15.0  ...            35.0
# 23            No                         NaN  ...            50.0
# 24            No                         NaN  ...            40.0
#
#    Power Dissipation(mW) Area (mm^2)  \
# 0                 0.8000       0.025
# 1                 0.7900       0.027
# 2                 1.4000       0.028
# 3                 5.2000       0.120
# 4                 0.9600       0.025
# 5                 2.0000       0.040
# 6                 9.0000         NaN
# 7                14.3000      0.0825
# 8                 1.0000       0.030
# 9                 0.1350        0.01
# 10                0.5500       0.008
# 11                0.1615       0.017
# 12                1.4200        0.12
# 13                0.7400        0.13
# 14                0.7000        0.13
# 15                0.7900       0.093
# 16                0.1600         0.2
# 17                3.8700        0.01
# 18                0.7910      0.0334
# 19                0.6000      0.0125
# 20                0.4202        0.15
# 21                1.0500        0.08
# 22                0.3720      0.0105
# 23                0.9000       0.034
# 24                0.5510      0.0077
#
#                                              DOI  \
# 0      https://doi.org/10.1109/JSSC.2022.3200160
# 1      https://doi.org/10.1109/JSSC.2018.2828826
# 2      https://doi.org/10.1109/JSSC.2015.2505714
# 3      https://doi.org/10.1109/JSSC.2020.3023618
# 4     https://doi.org/10.1109/TCSII.2021.3090424
# 5     https://doi.org/10.1109/TUFFC.2005.1563266
# 6        https://doi.org/10.1109/TUFFC.2009.1297
# 7      https://doi.org/10.1109/JSSC.2013.2274895
# 8   https://doi.org/10.1109/ESSCIRC.2014.6942108
# 9   https://doi.org/10.1109/ESSCIRC.2015.7313913
# 10                                           NaN
# 11     https://doi.org/10.1109/JSSC.2021.3049560
# 12     https://doi.org/10.1109/JSSC.2018.2820156
# 13     https://doi.org/10.1109/JSSC.2019.2921697
# 14    https://doi.org/10.1109/TBCAS.2018.2881909
# 15     https://doi.org/10.1109/JSSC.2020.2967551
# 16     https://doi.org/10.1109/JSSC.2023.3276130
# 17     https://doi.org/10.1109/JSSC.2017.2749425
# 18     https://doi.org/10.1109/JSSC.2024.3355854
# 19    https://doi.org/10.1109/TBCAS.2021.3135859
# 20    https://doi.org/10.1109/TCSII.2014.2327455
# 21    https://doi.org/10.1109/TBCAS.2015.2406777
# 22    https://doi.org/10.1109/TBCAS.2022.3205024
# 23    https://doi.org/10.1109/TBCAS.2018.2836915
# 24      https://doi.org/10.1109/ULTSYM.2014.0381
#
#                                                 Notes  \
# 0                                                 NaN
# 1   Originally observed effect of PSRR in inter-ch...
# 2   Defines an Acoustic Noise Efficiency Factor (A...
# 3                Establishes the basis of Pengs Work.
# 4    Uses a cross-coupled harmonic injection NMOS ...
# 5    Older work establishing which metrics to take...
# 6   Old technology with base work for CMUT-on-CMOS...
# 7    Very interesting charge-pump DC-DC converter ...
# 8    Defines a linearized approximation of the tra...
# 9    Very important base work defining the importa...
# 10                                                NaN
# 11                 Open Loop VA with 4-gain step PGA
# 12  Closed Loop (cap) folded cascode LNA with sing...
# 13  Open Loop differential pair with a pseudo-diff...
# 14  Closed Loop diff pair + CS output stage, resis...
# 15  CMUT-BSimulator Based Impedance  Calculator fo...
# 16  Rotating Single PZT Transducer insie Cabsule, ...
# 17  3 stage LNA-LPF-PGA based on inverter-based am...
# 18          "Capacitive Feedback TIA coupled to a PZT
# 19   Reference TIA implementation with noise figur...
# 20   Standard CMOS implementation of HV pulser usi...
# 21                                                NaN
# 22  First paper providing a reference microbeamfor...
# 23  Reference paper for implementing the testing s...
# 24  Quadrature FDM Simulated Results from Post Lay...
#
#                                           Unnamed: 28      PaperID  \
# 0                                                 NaN     JSSC2022
# 1                                                 NaN     JSSC2018
# 2                                                 NaN     JSSC2015
# 3                                                 NaN     JSSC2020
# 4                                                 NaN    TCSII2021
# 5                                                 NaN    TUFFC2005
# 6                                                 NaN    TUFFC2009
# 7                                                 NaN     JSSC2013
# 8                                                 NaN  ESSCIRC2014
# 9                                                 NaN  ESSCIRC2015
# 10                                                NaN          NaN
# 11                                                NaN     JSSC2021
# 12                                                NaN     JSSC2018
# 13                                                NaN     JSSC2019
# 14                                                NaN    TBCAS2018
# 15                                                NaN     JSSC2020
# 16                                                NaN     JSSC2023
# 17                                                NaN     JSSC2017
# 18   due to the PZT output impedance magnitude bei...     JSSC2024
# 19                                                NaN     JSSC2021
# 20                                                NaN    TCSII2014
# 21                                                NaN    TBCAS2015
# 22                                                NaN    TBCAS2022
# 23                                                NaN    TBCAS2018
# 24                                                NaN   ULTSYM2014
#
#     Architecture Category  Area ($mm^2$) FoM$_{LNA}$ (dB)
# 0                   CL-CA         0.0250        61.399481
# 1                     TIA         0.0270        55.064929
# 2                     TIA         0.0280        48.624721
# 3                   CL-CA         0.1200        52.352550
# 4                   OL-VA         0.0250        45.090905
# 5                     TIA         0.0400              NaN
# 6                     TIA            NaN        44.436975
# 7                     TIA         0.0825        35.770577
# 8                     TIA         0.0300        55.965971
# 9                   CL-VA         0.0100        68.608923
# 10                  OL-VA         0.0080              NaN
# 11                  OL-VA         0.0170        76.957708
# 12                  CL-VA         0.1200        51.487417
# 13                  OL-VA         0.1300        63.297383
# 14                  CL-VA         0.1300        48.662946
# 15                    TIA         0.0930        47.023729
# 16                  OL-VA         0.2000        76.872417
# 17                    TIA         0.0100        64.122890
# 18                    TIA         0.0334        63.271596
# 19                    TIA         0.0125        50.279400
# 20                    TIA         0.1500        54.557252
# 21                    TIA         0.0800        52.191734
# 22                    TIA         0.0105        50.086383
# 23                  OL-VA         0.0340        58.653014
# 24                    TIA         0.0077        55.598784
#
# [25 rows x 33 columns]

# %% [markdown]
# Additionally, let's add an additional column to classify TIA and non-TIA architectures.

# %%
lnareviewdf.columns
# Out:
# Index(['Group', 'Work', 'Technology', 'Transducer Type', 'Supply(V)', 'Lmin',
#        'Pitch(µm)', 'LNA Architecture', 'Pitch Matched',
#        'Transducer Capacitance (pF)', 'Continuous Time', 'TGC Modality',
#        'Max Gain(dB)', 'Gain Range(dB)', 'Gain Error(\pm dB)',
#        'Gain Settings #', 'Gain Step (dB)', 'Center Frequency (F0 MHz)',
#        '-3dB BW (MHz)', 'IRNC @ F0 (pA/\sqrt{Hz})', 'IRNV @ F0 (nV/\sqrt{Hz})',
#        'IRNA @ F0 (mPa/\sqrt{Hz})', 'PSRR @ F0(dBc)', 'Peak SNR@BW(dB)',
#        'Power Dissipation(mW)', 'Area (mm^2)', 'DOI', 'Notes', 'Unnamed: 28',
#        'PaperID', 'Architecture Category', 'Area ($mm^2$)',
#        'FoM$_{LNA}$ (dB)'],
#       dtype='object')

# %%
# Use the simpler, built-in MathText engine
plt.rcParams['text.usetex'] = False

# %%
CUSTOM_DOT_SIZE = 30 # Adjust this value (default is usually ~50)
MARKER_STYLES = ['^', 's', 'o', 'D'] # Triangle, Square, Circle, Diamond (add more as needed for your classes)
CUSTOM_COLORS = ['#648FFF', '#FE6100', '#DC267F', '#1D3557'] # Example colors (e.g., Red, Blue, Cyan, Dark Blue)

# %%
# plot voltage amplifiers versus TIA architectures, to observe how the choice of
# architecture affects overall performance of the main block of the AFE
fig, ax = plt.subplots(1,1, figsize=(4,4))
sns.scatterplot(
    data=lnareviewdf,
    x='Area ($mm^2$)',
    y='FoM$_{LNA}$ (dB)',
    hue='Architecture Category', # This is the column that distinguishes the classes
    style='Transducer Type',     # Controls shape/marker by class
    s=CUSTOM_DOT_SIZE,             # Sets the size of the dots
    markers=MARKER_STYLES,         # Assigns specific shapes to the classes
    palette='colorblind',         # Assigns specific colors to the classes
    ax=ax,
)

step_size = 5.0
num = int(50.0 / step_size)+1
ax.set_yticks(np.linspace(30.0, 80.0, num))
ax.set_xscale('log')

FOM_THRESHOLD = 62.5

for index, row in lnareviewdf.iterrows():
    # 2. Check the threshold to determine text and weight
    display_text = row['PaperID']
    if row['FoM$_{LNA}$ (dB)'] > FOM_THRESHOLD:
        display_text += ''  # Append the custom string
        text_weight = 'bold'           # Make it bold
    else:
        text_weight = 'normal'         # Keep it regular
    ax.annotate(
        display_text,                     # The text to display
        xy=(row['Area ($mm^2$)'], row['FoM$_{LNA}$ (dB)']),   # The exact coordinates of the dot
        xytext=(-15, 6),                           # The offset: (8 points right, 0 points up/down)
        textcoords='offset points',              # Tells matplotlib to use points for the offset
        ha='left',                               # Horizontal alignment
        va='center',                             # Vertical alignment (keeps it centered with the dot)
        size='medium',
        color='black',
        weight=text_weight
    )

# 1. Add the Target Arrow pointing to the top-left
ax.annotate(
    'Target', 
    xy=(0.01, 0.99),             # The point of the arrow (5% from left, 95% from bottom)
    xytext=(0.15, 0.85),         # The location of the text
    xycoords='axes fraction',    # Use the plot's bounding box, not the data scale
    textcoords='axes fraction',  
    fontsize=12,
    fontweight='bold',
    color='green',
    arrowprops=dict(
        facecolor='green',       # Arrow color
        shrink=0.05,             # Leaves a tiny gap between the text/edge and the arrow
        width=2,                 # Thickness of the arrow tail
        headwidth=10             # Thickness of the arrow head
    )
)

ax.grid(linestyle='--', alpha=0.5, which='both')
#ax.set_yscale('log')
ax.legend(title='',frameon=True, loc='lower left',facecolor='gray', framealpha=0.2, edgecolor='none', fontsize=6)
fig.tight_layout()
fig.savefig(dir/'lna_architecture_survey.pdf', dpi=300)
# Out:
# /var/folders/vv/xctyh4bd2td6k2w_gvh_t2vr0000gn/T/ipykernel_34254/1167973513.py:4: UserWarning: The markers list has more values (4) than needed (3), which may not be intended.
#   sns.scatterplot(

# %%
lnareviewdf.to_csv(dir/'us_lna_survey_post_processed.csv')
